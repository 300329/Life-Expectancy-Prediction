# %%
import pandas as pd
data=pd.read_csv( "C:/Users/gopav/Downloads/archive (7)/Life Expectancy Data.csv")
data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
data.shape
# Out:
# (2938, 22)

# %%
print(data.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['Country']=encoder.fit_transform(data['Country'])
data['Status']=encoder.fit_transform(data['Status'])
data.head()
# Out:
#    Country  Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0        0  2015       1              65.0            263.0             62
# 1        0  2014       1              59.9            271.0             64
# 2        0  2013       1              59.9            268.0             66
# 3        0  2012       1              59.5            272.0             69
# 4        0  2011       1              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
correlation_value=data.corr()
correlation_value
# Out:
#                                   Country      Year    Status  \
# Country                          1.000000  0.001342 -0.031635
# Year                             0.001342  1.000000  0.001864
# Status                          -0.031635  0.001864  1.000000
# Life expectancy                 -0.016763  0.170033 -0.482136
# Adult Mortality                  0.039802 -0.079052  0.315284
# infant deaths                   -0.030528 -0.037415  0.112252
# Alcohol                         -0.062134 -0.052990 -0.596660
# percentage expenditure          -0.032983  0.031400 -0.454261
# Hepatitis B                     -0.020741  0.104333 -0.115317
# Measles                         -0.024593 -0.082493  0.076955
#  BMI                             0.017860  0.108974 -0.311257
# under-five deaths               -0.026509 -0.042937  0.115195
# Polio                            0.017807  0.094158 -0.220250
# Total expenditure                0.055374  0.090740 -0.299990
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
sns.heatmap(correlation_value,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
data=data.drop(columns=['Year'])   # Not necessary column for predicting life expectancny(low positive corrleation)
data.head()
# Out:
#    Country  Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0        0       1              65.0            263.0             62     0.01
# 1        0       1              59.9            271.0             64     0.01
# 2        0       1              59.9            268.0             66     0.01
# 3        0       1              59.5            272.0             69     0.01
# 4        0       1              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               71.279624         65.0      1154   19.1  ...    6.0
# 1               73.523582         62.0       492   18.6  ...   58.0
# 2               73.219243         64.0       430   18.1  ...   62.0
# 3               78.184215         67.0      2787   17.6  ...   67.0
# 4                7.097109         68.0      3013   17.2  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data=data.drop(columns=['Country'])   # Not necessary column for predicting life expectancny(low Negative corrleation)
data.head()
# Out:
#    Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0       1              65.0            263.0             62     0.01
# 1       1              59.9            271.0             64     0.01
# 2       1              59.9            268.0             66     0.01
# 3       1              59.5            272.0             69     0.01
# 4       1              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
data.isna().sum()
# Out:
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data = data.fillna(0)  #here all all null values are filled with 0 or fill with mean, median or mode etc.
data.isna().sum()
# Out:
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
import pandas as pd
data=pd.read_csv( "C:/Users/gopav/Downloads/archive (7)/Life Expectancy Data.csv")
data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
import matplotlib.pyplot as plt
print(data.columns)
data.columns = data.columns.str.strip()
plt.figure(figsize=(10, 6))
plt.plot(data['Year'], data['Life expectancy'])
plt.title('Life expectancy  Over Years')
plt.xlabel('Year')
plt.ylabel('Life expectancy')
plt.show()
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data.columns = data.columns.str.strip()
plt.figure(figsize=(10, 6))
sns.histplot(data['Adult Mortality'], bins=20) 
plt.title('Histogram')
plt.xlabel('Adult Mortality')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\gopav\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.columns = data.columns.str.strip()
plt.figure(figsize=(10, 6))
sns.boxplot(x=data['Adult Mortality'])
plt.title('Boxplot ')
plt.xlabel('Adult Mortality')
plt.show()

# %%
import matplotlib.pyplot as plt
data.columns = data.columns.str.strip()
status = data['Status'].value_counts()
plt.figure(figsize=(8, 8))  # Set the figure size
plt.pie(status, labels=status.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of developed vs developing')
plt.show()  # Display the pie chart

# %%
x=data.drop(columns=["Life expectancy"])
y=data["Life expectancy"]

# %%
x
# Out:
#       Status  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0          1            263.0             62     0.01               71.279624
# 1          1            271.0             64     0.01               73.523582
# 2          1            268.0             66     0.01               73.219243
# 3          1            272.0             69     0.01               78.184215
# 4          1            275.0             71     0.01                7.097109
# ...      ...              ...            ...      ...                     ...
# 2933       1            723.0             27     4.36                0.000000
# 2934       1            715.0             26     4.06                0.000000
# 2935       1             73.0             25     4.43                0.000000
# 2936       1            686.0             25     1.72                0.000000
# 2937       1            665.0             24     1.68                0.000000
#
# ...

# %%
y
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=34)

# %%
x_train
# Out:
#       Status  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1378       1            198.0              0     0.00                0.000000
# 1985       1             37.0             11     0.84               12.055520
# 2033       1            223.0             65     4.22              105.730698
# 1610       1             82.0              0     1.78                6.491489
# 831        1             24.0              3     2.97               29.685294
# ...      ...              ...            ...      ...                     ...
# 1571       1            377.0             27     0.01               59.487449
# 324        1             92.0              0     4.64                7.959131
# 1897       1            375.0            513     8.75              187.573319
# 2538       1            294.0              7     0.01                0.000000
# 1146       1             16.0              5     3.16              222.482334
#
# ...

# %%
x_test
# Out:
#       Status  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 2199       1            186.0              0     4.80                0.000000
# 123        0             69.0              1     9.84              588.568371
# 1426       1            194.0              8     0.00                0.000000
# 2544       1            122.0              8     0.80                0.000000
# 274        1            251.0             25     0.01               87.408042
# ...      ...              ...            ...      ...                     ...
# 1648       0             79.0              0     5.62              130.015039
# 2903       1             25.0             45     0.07                0.000000
# 1710       1            179.0              0     2.02                0.000000
# 2484       1            214.0              0     4.55                4.232577
# 912        1            221.0              0     1.93               20.711913
#
# ...

# %%
y_train
# Out:
# 1378    66.3
# 1985    64.0
# 2033    67.0
# 1610    75.4
# 831     73.0
#         ...
# 1571    57.6
# 324     76.9
# 1897    52.3
# 2538    64.4
# 1146    73.0
# Name: Life expectancy, Length: 2350, dtype: float64

# %%
y_test
# Out:
# 2199    79.0
# 123     86.0
# 1426    65.7
# 2544    73.8
# 274     59.5
#         ...
# 1648    77.8
# 2903    61.5
# 1710    67.7
# 2484    68.3
# 912     67.8
# Name: Life expectancy, Length: 588, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_pred=model.predict(x_test)
y_test_pred
# Out:
# array([63.65571006, 79.21058087, 67.15578509, 68.08468507, 63.40780252,
#        77.68541131, 81.90792003, 75.55832068, 55.77087394, 68.0546499 ,
#        62.28321051, 67.71755728, 68.79912305, 77.06197409, 70.3906844 ,
#        70.54966061, 80.78602808, 80.74425175, 76.41186178, 69.32645927,
#        75.10993321, 81.63253823, 69.91239013, 69.51406145, 59.83956921,
#        75.28489043, 74.51108393, 66.26934921, 68.80020655, 75.05412144,
#        75.79387118, 76.07764893, 74.67400082, 82.88562193, 74.67474191,
#        75.54857164, 63.58765425, 69.96249081, 71.38676371, 67.20181484,
#        71.55179218, 73.35326823, 79.06250231, 68.0065853 , 74.67301903,
#        71.37594423, 81.5943191 , 59.1050828 , 70.01598432, 70.47232152,
#        55.29611243, 51.74937711, 62.8732741 , 74.64237698, 70.30545832,
#        66.99889633, 60.48295147, 72.41637484, 64.14448464, 60.37720535,
#        65.85062901, 61.29649787, 65.75393817, 78.98521371, 76.03710415,
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
y_test_score=mean_squared_error(y_test,y_test_pred)
y_test_score
# Out:
# 40.238772327607

# %%
specific_row = pd.DataFrame({
    'Status':[1],
    'Adult Mortality':[293],                     
    'infant deaths':[87],                     
    'Alcohol':[0.02] ,                           
    'percentage expenditure':[15.29606643],              
    'Hepatitis B':[67],                       
    'Measles':[466] ,                             
    'BMI':[13.8] ,                              
    'under-five deaths':[120] ,                   
    'Polio':[5],                               
    'Total expenditure':[8.79] ,                 
    'Diphtheria':[5],                         
    'HIV/AIDS':[0.1] ,                           
    'GDP':[219.1413528] ,                             
    'Population':[24118979],                        
    'thinness  1-19 years':[19.5],               
     'thinness 5-9 years':[19.7],                 
     'Income composition of resources':[0.381],
      'Schooling':[6.8]
})
predicted_value = model.predict(specific_row)
print(f'Predicted Life Expectancy: {predicted_value[0]}')
# Out:
# Predicted Life Expectancy: 56.442645310107224

# %%
#give life expectancy of taken row is 57
and predicted life expectancy is  56.442645310107224
So our model linear regression accurately predict the life expectancy

# %%
from sklearn.metrics import r2_score

# %%
y_test_score=r2_score(y_test,y_test_pred)
y_test_score
# Out:
# 0.5973082661517877
